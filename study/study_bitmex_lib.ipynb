# %%
import bitmex
import settings as s

# %%
client = bitmex.bitmex(api_key=s.API_KEY, api_secret=s.API_SECRET)

# %%
data = client.Trade.Trade_getBucketed(
    binSize = '5m',
    symbol='XBTUSD',
    count=10,
    reverse=True
).result()

# %%
data
# Out:
# ([{'timestamp': datetime.datetime(2019, 4, 22, 8, 55, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'open': 5280.0,
#    'high': 5285.0,
#    'low': 5280.0,
#    'close': 5284.5,
#    'trades': 151,
#    'volume': 93596,
#    'vwap': 5283.1784,
#    'lastSize': 40,
#    'turnover': 1771585975,
#    'homeNotional': 17.71585975,
#    'foreignNotional': 93596.0},
#   {'timestamp': datetime.datetime(2019, 4, 22, 8, 50, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'open': 5279.5,
#    'high': 5280.5,
#    'low': 5278.5,
#    'close': 5280.0,
#    'trades': 37,
#    'volume': 3845,
#    'vwap': 5280.1098,
#    'lastSize': 1,
#    'turnover': 72823997,
#    'homeNotional': 0.72823997,
#    'foreignNotional': 3845.0},
#   {'timestamp': datetime.datetime(2019, 4, 22, 8, 45, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'open': 5280.0,
#    'high': 5280.0,
#    'low': 5278.0,
#    'close': 5279.5,
#    'trades': 58,
#    'volume': 5648,
#    'vwap': 5278.7162,
#    'lastSize': 1,
# ...

# %%
data[0]
# Out:
# [{'timestamp': datetime.datetime(2019, 4, 22, 8, 55, tzinfo=tzutc()),
#   'symbol': 'XBTUSD',
#   'open': 5280.0,
#   'high': 5285.0,
#   'low': 5280.0,
#   'close': 5284.5,
#   'trades': 151,
#   'volume': 93596,
#   'vwap': 5283.1784,
#   'lastSize': 40,
#   'turnover': 1771585975,
#   'homeNotional': 17.71585975,
#   'foreignNotional': 93596.0},
#  {'timestamp': datetime.datetime(2019, 4, 22, 8, 50, tzinfo=tzutc()),
#   'symbol': 'XBTUSD',
#   'open': 5279.5,
#   'high': 5280.5,
#   'low': 5278.5,
#   'close': 5280.0,
#   'trades': 37,
#   'volume': 3845,
#   'vwap': 5280.1098,
#   'lastSize': 1,
#   'turnover': 72823997,
#   'homeNotional': 0.72823997,
#   'foreignNotional': 3845.0},
#  {'timestamp': datetime.datetime(2019, 4, 22, 8, 45, tzinfo=tzutc()),
#   'symbol': 'XBTUSD',
#   'open': 5280.0,
#   'high': 5280.0,
#   'low': 5278.0,
#   'close': 5279.5,
#   'trades': 58,
#   'volume': 5648,
#   'vwap': 5278.7162,
#   'lastSize': 1,
#   'turnover': 107000330,
# ...

# %%
import pandas as pd

# %%
pf = pd.DataFrame(data[0])

# %%
pf.set_index(['timestamp'], inplace=True)

# %%
pf
# Out:
#                             close  foreignNotional    high  homeNotional  \
# timestamp
# 2019-04-22 08:55:00+00:00  5284.5          93596.0  5285.0     17.715860
# 2019-04-22 08:50:00+00:00  5280.0           3845.0  5280.5      0.728240
# 2019-04-22 08:45:00+00:00  5279.5           5648.0  5280.0      1.070003
# 2019-04-22 08:40:00+00:00  5280.0           3104.0  5281.0      0.587887
# 2019-04-22 08:35:00+00:00  5280.5          68325.0  5282.5     12.938867
# 2019-04-22 08:30:00+00:00  5279.5          38307.0  5282.0      7.256411
# 2019-04-22 08:25:00+00:00  5278.0          44680.0  5282.0      8.461731
# 2019-04-22 08:20:00+00:00  5281.0          56678.0  5283.0     10.733103
# 2019-04-22 08:15:00+00:00  5276.5          24159.0  5276.5      4.579911
# 2019-04-22 08:10:00+00:00  5276.5          22503.0  5279.0      4.264010
#
#                            lastSize     low    open  symbol  trades  \
# timestamp
# 2019-04-22 08:55:00+00:00        40  5280.0  5280.0  XBTUSD     151
# ...

# %%
pf.close
# Out:
# timestamp
# 2019-04-22 08:55:00+00:00    5284.5
# 2019-04-22 08:50:00+00:00    5280.0
# 2019-04-22 08:45:00+00:00    5279.5
# 2019-04-22 08:40:00+00:00    5280.0
# 2019-04-22 08:35:00+00:00    5280.5
# 2019-04-22 08:30:00+00:00    5279.5
# 2019-04-22 08:25:00+00:00    5278.0
# 2019-04-22 08:20:00+00:00    5281.0
# 2019-04-22 08:15:00+00:00    5276.5
# 2019-04-22 08:10:00+00:00    5276.5
# Name: close, dtype: float64

# %%
pf.close.values
# Out:
# array([5284.5, 5280. , 5279.5, 5280. , 5280.5, 5279.5, 5278. , 5281. ,
#        5276.5, 5276.5])

# %%
import talib

# %%
candles = pd.DataFrame(client.Trade.Trade_getBucketed(
            binSize='5m',
            symbol='XBTUSD',
            count=100,
            reverse=True
        ).result()[0])

# %%
macd, signal, hist = talib.MACD(candles.close.values,
                                        fastperiod=8, slowperiod=28, signalperiod=9)

# %%
macd
# Out:
# array([        nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#         0.74818915,  1.17944712,  0.70737804,  0.35469387,  1.01340619,
#         0.24882   , -0.4619159 ,  0.10328938,  0.43436463,  0.7440802 ,
#         1.41672358,  1.95872628,  2.24456385,  2.11063682,  1.82805154,
#         0.98237789,  0.96796474,  0.55955117, -1.73710926, -3.14370076,
#        -4.03745935, -3.47336179, -2.9350174 , -3.87951104, -4.19748519,
#        -5.35958164, -6.19558893, -6.55276526, -5.86807279, -4.36278863,
# ...

# %%
signal
# Out:
# array([        nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#        -0.47170895, -0.14147773,  0.02829342,  0.09357351,  0.27754005,
#         0.27179604,  0.12505365,  0.1207008 ,  0.18343356,  0.29556289,
#         0.51979503,  0.80758128,  1.09497779,  1.2981096 ,  1.40409799,
#         1.31975397,  1.24939612,  1.11142713,  0.54171985, -0.19536427,
#        -0.96378329, -1.46569899, -1.75956267, -2.18355234, -2.58633891,
#        -3.14098746, -3.75190775, -4.31207926, -4.62327796, -4.5711801 ,
# ...

# %%
hist
# Out:
# array([        nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#         1.21989809,  1.32092486,  0.67908462,  0.26112036,  0.73586614,
#        -0.02297604, -0.58696955, -0.01741142,  0.25093107,  0.44851731,
#         0.89692855,  1.151145  ,  1.14958605,  0.81252722,  0.42395356,
#        -0.33737608, -0.28143138, -0.55187596, -2.27882911, -2.94833649,
#        -3.07367607, -2.0076628 , -1.17545473, -1.69595869, -1.61114628,
#        -2.21859418, -2.44368118, -2.24068601, -1.24479483,  0.20839147,
# ...
